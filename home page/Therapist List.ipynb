# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/tikaramadhini/Documents/theraplydata/thedata/therapistsdata.csv', encoding_errors='ignore', sep=';', index_col='Number')

# %%
df
# Out:
#                                        Name  Gender Personal Therapy  \
# Number
# NaN                 Prof.Dr.Dr. Rainer Kaus    Male              Yes
# 2.0                      Dr. Hannsi Padberg  Female              Yes
# 3.0     Dipl.-Psych. Reiner Domes-Nontasila    Male              Yes
# 4.0                      Dr. Walter Raffauf    Male              Yes
# 5.0              Dipl.-Psych. Frank Taffelt    Male              Yes
# 6.0                        Dr. Petra Zinser  Female              Yes
# 7.0                     Prof. Frank Lehmann    Male              Yes
# 8.0                         Dr. Andrea Dorn  Female              Yes
# 9.0                       Dr. Stephan Heyne    Male              Yes
# 10.0           Dipl.-Psych. Bettina Wallner  Female              Yes
# 11.0                     Dr. Claudia Thubas  Female              Yes
# 12.0            Dipl.-Psych. Tilman Reutter    Male              Yes
# ...

# %%
df.shape
# Out:
# (21, 16)
